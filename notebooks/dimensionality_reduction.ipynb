# %% [markdown]
# # Dimensionality Reduction
# In this notebook, we compare multivariate ClaSP with dimensionality reduction.

# %%
# needed fpr PDF/A
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

from aeon.visualisation import plot_critical_difference
from external.MCM import MCM
from wand.image import Image

sns.set_theme()
sns.set_color_codes()

import os
import sys

sys.path.append("../../")

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["PCA", "ICA", "RP"]
datasets = ["HAS_train"] #    

methods, dfs = list(), list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    df = []
    
    for d in datasets:
        df.append(pd.read_csv(f"../experiments/ablation_study/{d}_{file_name}", usecols=["dataset", eval_score], compression="gzip"))
    
    df = pd.concat(df)
    df.sort_values(by="dataset", inplace=True)
    dfs.append((name, df))

df_scores = pd.DataFrame()

for name, df in dfs:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]

df_scores.reset_index(drop=True, inplace=True)
df_scores
# Out:
#                                dataset    PCA    ICA     RP
# 0     indoor_subject1_routine1 (id140)  0.485  0.565  0.930
# 1     indoor_subject1_routine1 (id150)  0.948  0.397  0.793
# 2      indoor_subject1_routine1 (id93)  0.562  0.450  0.815
# 3     indoor_subject1_routine2 (id127)  0.218  0.218  0.218
# 4     indoor_subject1_routine2 (id177)  0.669  0.669  0.669
# 5     indoor_subject1_routine3 (id180)  0.647  0.590  0.512
# 6     indoor_subject2_routine1 (id176)  0.646  0.642  0.587
# 7     indoor_subject2_routine1 (id227)  0.802  0.400  0.780
# 8     indoor_subject2_routine1 (id231)  0.578  0.392  0.296
# 9      indoor_subject2_routine1 (id66)  0.158  0.327  0.158
# 10    indoor_subject2_routine2 (id129)  0.178  0.178  0.178
# 11     indoor_subject2_routine2 (id36)  0.130  0.130  0.279
# 12    indoor_subject3_routine1 (id164)  0.254  0.254  0.725
# 13    indoor_subject3_routine1 (id209)  0.627  0.540  0.909
# 14    indoor_subject3_routine1 (id233)  0.753  0.760  0.748
# 15     indoor_subject3_routine1 (id88)  0.630  0.630  0.619
# 16     indoor_subject3_routine1 (id91)  0.408  0.408  0.422
# 17    indoor_subject3_routine2 (id114)  0.436  0.418  0.436
# 18    indoor_subject3_routine2 (id130)  0.466  0.466  0.466
# 19    indoor_subject3_routine2 (id202)  0.696  0.592  0.540
# 20    indoor_subject3_routine3 (id109)  0.961  0.918  0.984
# 21    indoor_subject3_routine3 (id186)  0.710  0.496  0.660
# 22     indoor_subject3_routine3 (id19)  0.933  0.931  0.381
# 23    indoor_subject3_routine3 (id192)  0.379  0.379  0.974
# 24     indoor_subject3_routine3 (id86)  0.630  0.630  0.649
# 25     indoor_subject4_routine1 (id14)  0.681  0.466  0.552
# 26    indoor_subject4_routine1 (id149)  0.654  0.729  0.622
# 27     indoor_subject4_routine1 (id24)  0.635  0.635  0.601
# 28     indoor_subject4_routine1 (id28)  0.950  0.810  0.908
# 29     indoor_subject4_routine2 (id21)  0.436  0.436  0.472
# 30    indoor_subject4_routine2 (id245)  0.641  0.641  0.447
# 31     indoor_subject4_routine2 (id77)  0.307  0.307  0.364
# 32    indoor_subject4_routine3 (id145)  0.884  0.874  0.628
# 33    indoor_subject4_routine3 (id215)  0.853  0.817  0.651
# 34     indoor_subject4_routine3 (id68)  0.894  0.805  0.691
# 35    indoor_subject5_routine3 (id210)  0.643  0.628  0.604
# 36    indoor_subject5_routine3 (id216)  0.638  0.798  0.521
# 37    indoor_subject5_routine3 (id217)  0.991  0.991  0.983
# 38    indoor_subject6_routine1 (id153)  0.490  0.706  0.527
# 39    indoor_subject6_routine3 (id199)  0.710  0.710  0.774
# 40     indoor_subject6_routine3 (id30)  0.763  0.746  0.818
# 41    indoor_subject7_routine1 (id200)  0.339  0.181  0.808
# 42    indoor_subject7_routine1 (id247)  0.673  0.158  0.564
# 43     indoor_subject7_routine1 (id49)  0.143  0.143  0.509
# 44     indoor_subject7_routine2 (id23)  0.188  0.188  0.339
# 45     indoor_subject7_routine2 (id41)  0.475  0.470  0.484
# 46    indoor_subject7_routine3 (id105)  0.605  0.580  0.992
# 47     indoor_subject7_routine3 (id12)  0.621  0.621  0.621
# 48    indoor_subject7_routine3 (id169)  1.000  1.000  1.000
# 49    indoor_subject7_routine3 (id196)  0.981  0.981  0.939
# 50      indoor_subject7_routine3 (id2)  0.726  0.726  0.714
# 51    indoor_subject7_routine3 (id238)  0.603  0.603  0.603
# 52    indoor_subject7_routine3 (id246)  0.525  0.525  0.632
# 53     indoor_subject7_routine3 (id59)  1.000  1.000  1.000
# 54     indoor_subject8_routine1 (id72)  0.190  0.091  0.465
# 55     indoor_subject8_routine3 (id11)  0.228  0.228  0.228
# 56    indoor_subject8_routine3 (id167)  0.695  0.738  0.886
# 57     indoor_subject8_routine3 (id55)  0.996  0.977  0.981
# 58    outdoor_subject1_routine1 (id16)  0.945  0.945  0.969
# 59   outdoor_subject1_routine1 (id165)  0.584  0.570  0.488
# 60   outdoor_subject1_routine2 (id119)  0.198  0.421  0.403
# 61   outdoor_subject2_routine1 (id110)  1.000  1.000  0.700
# 62   outdoor_subject2_routine1 (id168)  1.000  1.000  1.000
# 63   outdoor_subject2_routine1 (id178)  0.722  0.722  0.394
# 64   outdoor_subject2_routine1 (id243)  0.976  0.976  0.949
# 65    outdoor_subject2_routine1 (id40)  0.876  0.873  0.912
# 66   outdoor_subject2_routine2 (id166)  0.432  0.730  0.329
# 67   outdoor_subject2_routine3 (id184)  0.524  0.168  0.456
# 68    outdoor_subject2_routine3 (id92)  0.377  0.275  0.233
# 69   outdoor_subject3_routine1 (id136)  0.252  0.252  0.872
# 70    outdoor_subject3_routine1 (id64)  0.792  0.791  0.781
# 71   outdoor_subject3_routine2 (id179)  0.435  0.435  0.441
# 72   outdoor_subject3_routine2 (id187)  0.453  0.453  0.453
# 73    outdoor_subject3_routine2 (id32)  0.348  0.348  0.281
# 74    outdoor_subject3_routine2 (id38)  0.401  0.401  0.401
# 116  outdoor_subject7_routine3 (id189)  0.340  0.340  0.551
# 117  outdoor_subject7_routine3 (id193)  0.903  0.250  0.744
# 118  outdoor_subject7_routine3 (id219)  1.000  1.000  1.000
# 119    outdoor_subject7_routine3 (id4)  1.000  1.000  1.000
# 120   outdoor_subject7_routine3 (id46)  0.829  0.829  0.844
# 121   outdoor_subject7_routine3 (id47)  0.999  0.999  0.972
# 122   outdoor_subject7_routine3 (id48)  1.000  1.000  1.000
# 123   outdoor_subject7_routine3 (id67)  0.767  0.770  0.775
# 124   outdoor_subject7_routine3 (id79)  1.000  1.000  1.000

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.iloc[:,1:].mean(axis=0).sort_values(ascending=False).round(3)
# Out:
# RP     0.666
# PCA    0.643
# ICA    0.627
# dtype: float64

# %%
df_scores.iloc[:,1:].median(axis=0).sort_values(ascending=False).round(3)
# Out:
# PCA    0.646
# RP     0.638
# ICA    0.630
# dtype: float64

# %%
df_scores.iloc[:,1:].std(axis=0).sort_values().round(3)
# Out:
# RP     0.237
# PCA    0.259
# ICA    0.265
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.iloc[:,1:].rank(1, method='min', ascending=False)
means = np.array(ranks.mean(axis=0))
args = np.argsort(means)

# %%
for mean, name in zip(means[args], df_scores.columns[1:].to_numpy()[args]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# PCA:wins=71 rank=1.5
# ICA:wins=56 rank=1.7
# RP:wins=71 rank=1.7

# %% [markdown]
# Let's plot the CD diagram.

# %%
ax = plot_critical_difference(
    scores=df_scores.iloc[:, 1:].to_numpy(),
    labels=df_scores.columns[1:].to_numpy(),
    correction="holm",
    alpha=0.05,
)

plt.savefig("../figures/cd_segmentation_dimensionality_reduction.pdf", bbox_inches="tight")
# Out:
# /var/folders/1m/8xt9fm8d1575s4p3vrgccf7r0000gn/T/ipykernel_5777/463480353.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig("../figures/cd_segmentation_dimensionality_reduction.pdf", bbox_inches="tight")
# /Users/ermshaua/miniconda3/envs/mclasp/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
#  Let's plot the MCM.

# %%
dir_path = "../figures/"
file_name = "mcm_segmentation_dimensionality_reduction"

MCM.compare(
    output_dir=dir_path,
    used_statistic="Score",
    save_as_json=False,
    df_results=df_scores.iloc[:, 1:],
    pdf_savename=file_name,
    load_analysis=False,
    pvalue_correction="Holm",
    row_comparates=("PCA",),
    fig_size=(20,5),
    font_size=18,
    precision=3
)
Image(filename=os.path.join(dir_path, file_name + ".pdf"))
# Out:
# Processing RP, ICA:   0%|          | 0/3 [00:00<?, ?it/s]
# <wand.image.Image: d87bf25 'PDF' (1439x349)>

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "PCA"

for rival in df_scores.columns[1:]:
    if rival == selection: continue

    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method='min', ascending=False)

    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]

    assert wins + losses + ties == pair_ranks.shape[0]

    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# PCA vs ICA: (wins/ties/losses): 37/69/19
# PCA vs RP: (wins/ties/losses): 48/29/48

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(5, 5))

# sort by median performance
df_sorted_scores = df_scores[df_scores.iloc[:, 1:].median(axis=0).sort_values().index]

df_sorted_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)

ax.set_xticklabels(df_sorted_scores.columns, rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0 + .2, .2), 1))

plt.savefig(f"../figures/bp_segmentation_dimensionality_reduction.pdf", bbox_inches="tight")
