# %% [markdown]
# # Change Point Selection Plot
# In this notebook, we show multivariate ClaSP segmentations and their deduplication.

# %%
# needed fpr PDF/A
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

from sklearn.cluster import AgglomerativeClustering
from src.utils import load_raw_has_datasets
from claspy.segmentation import BinaryClaSPSegmentation
from sklearn.decomposition import PCA, FastICA
from sklearn.random_projection import GaussianRandomProjection

import os
import sys

sys.path.append("../../")

# %% [markdown]
# Let's start by loading the data and selecting a time series.

# %%
df_data = load_raw_has_datasets()
df_data.head()
# Out:
#    ts_id  ts_challenge_id   group  subject  routine  \
# 0      0              125  indoor        1        1
# 1      1              140  indoor        1        1
# 2      2               93  indoor        1        1
# 3      3               52  indoor        1        1
# 4      4              221  indoor        1        1
#
#                          change_points  \
# 0       [1461, 2952, 4473, 5022, 6460]
# 1  [772, 2056, 3521, 4835, 5283, 6893]
# 2       [1211, 2043, 2836, 3529, 4036]
# 3        [739, 1433, 2044, 2875, 3589]
# 4       [1506, 3033, 4477, 5348, 6805]
#
#                                           activities    split  \
# 0  [jumping jacks, downtoplank, jumping jacks, re...  private
# 1  [rest, plank, sit ups, plank, rest, jumping ja...   public
# 2  [plank, squat jump, lunges left, lunges right,...   public
# 3  [lunges left, lunges right, rest, squat jump, ...  private
# 4  [hiptrust, diagonal, hiptrust, rest, diagonal,...  private
#
# ...

# %%
idx = 0
row = df_data.iloc[idx, :]

T = row.iloc[8:17].tolist()

# %% [markdown]
# We compute the CPs and plot them.

# %%
P = []
C = []

for time_series in T:
    clasp = BinaryClaSPSegmentation(window_size=50)
    C.append(clasp.fit_predict(time_series))
    P.append(clasp.profile)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/ermshaua/miniconda3/envs/mclasp/lib/python3.9/site-packages/claspy/nearest_neighbour.py:240: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   start, end = pranges[idx]

# %%
found_cps = np.concatenate(C)
clu = AgglomerativeClustering(n_clusters=None, linkage="average", distance_threshold=5 * clasp.window_size)
clusters = clu.fit_predict(found_cps.reshape(-1, 1))

merged_cps = []

for label in np.unique(clusters):
    candidates = found_cps[clusters == label]

    if len(candidates) < 4: continue
    merged_cps.append(int(np.mean(candidates)))

found_cps = np.sort(merged_cps)

# %%
title = f"ClaSP Profiles for TS#{row.ts_id+1} ({', '.join(row.activities)})"
time_series = P + [np.zeros(0), np.zeros(0), np.zeros(0)]
sensor_names = [""] * (len(time_series)-1) + ["SEL"] # df_data.columns[8:17].tolist()
change_points = row.change_points
activities = row.activities
font_size = 18

fig, axes = plt.subplots(
    len(time_series),
    sharex=True,
    gridspec_kw={'hspace': .1},
    figsize=(20, len(time_series) // 2)
)

activity_colours = {}
idx = 0

for activity in activities:
    if activity not in activity_colours:
        activity_colours[activity] = f"C{idx}"
        idx += 1

for idx, (ts, sensor, ax) in enumerate(zip(time_series, sensor_names, axes)):
    if len(ts) > 0:
        segments = [0] + change_points.tolist() + [ts.shape[0]]
        for kdx in np.arange(0, len(segments) - 1):
            ax.plot(
                np.arange(segments[kdx], segments[kdx + 1]),
                ts[segments[kdx]:segments[kdx + 1]],
                c=activity_colours[activities[kdx]],
                alpha=0.5 if idx < len(time_series) - 3 else 1
            )
        
        for cp in C[idx]:
            ax.axvline(x=cp, linewidth=2, color='red', linestyle="dashed")
            
    if idx == len(time_series)-1:
        for cp in found_cps:
            ax.axvline(x=cp, linewidth=2, color='red', linestyle="dashed")

    ax.set_ylabel(sensor, fontsize=12)

    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(font_size)

    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(font_size)
        
    ax.set_facecolor((1., 1., 1.))
        
    ax.tick_params(
        axis='both',          
        which='both',      
        labelbottom=False,
        labelleft=False
    )

axes[0].set_title(title, fontsize=18)

plt.savefig("../figures/cp_selection.pdf", bbox_inches="tight")
