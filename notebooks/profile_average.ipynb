# %% [markdown]
# # Profile Average
# In this notebook, we compare multivariate ClaSP with profile averaging.

# %%
# needed fpr PDF/A
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

from aeon.visualisation import plot_critical_difference
from external.MCM import MCM
from wand.image import Image

sns.set_theme()
sns.set_color_codes()

import os
import sys

sys.path.append("../../")

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ProfileAvg", "MaxProfileAvg", "ThresholdProfileAvg"]
datasets = ["HAS_train"] #    

methods, dfs = list(), list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    df = []
    
    for d in datasets:
        df.append(pd.read_csv(f"../experiments/ablation_study/{d}_{file_name}", usecols=["dataset", eval_score], compression="gzip"))
    
    df = pd.concat(df)
    df.sort_values(by="dataset", inplace=True)
    dfs.append((name, df))

df_scores = pd.DataFrame()

for name, df in dfs:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]

df_scores.reset_index(drop=True, inplace=True)
df_scores
# Out:
#                                dataset  ProfileAvg  MaxProfileAvg  \
# 0     indoor_subject1_routine1 (id140)       0.496          0.483
# 1     indoor_subject1_routine1 (id150)       0.522          0.763
# 2      indoor_subject1_routine1 (id93)       0.858          0.672
# 3     indoor_subject1_routine2 (id127)       0.218          0.505
# 4     indoor_subject1_routine2 (id177)       0.702          0.702
# 5     indoor_subject1_routine3 (id180)       0.489          0.491
# 6     indoor_subject2_routine1 (id176)       0.619          0.632
# 7     indoor_subject2_routine1 (id227)       0.792          0.946
# 8     indoor_subject2_routine1 (id231)       0.596          0.850
# 9      indoor_subject2_routine1 (id66)       0.772          0.928
# 10    indoor_subject2_routine2 (id129)       0.421          0.533
# 11     indoor_subject2_routine2 (id36)       0.313          0.463
# 12    indoor_subject3_routine1 (id164)       0.957          0.848
# 13    indoor_subject3_routine1 (id209)       0.644          0.695
# 14    indoor_subject3_routine1 (id233)       0.964          0.960
# 15     indoor_subject3_routine1 (id88)       0.912          0.758
# 16     indoor_subject3_routine1 (id91)       0.844          0.928
# 17    indoor_subject3_routine2 (id114)       0.436          0.454
# 18    indoor_subject3_routine2 (id130)       0.426          0.475
# 19    indoor_subject3_routine2 (id202)       0.524          0.539
# 20    indoor_subject3_routine3 (id109)       0.975          0.967
# 21    indoor_subject3_routine3 (id186)       0.715          0.629
# 22     indoor_subject3_routine3 (id19)       0.727          0.596
# 23    indoor_subject3_routine3 (id192)       0.905          0.775
# 24     indoor_subject3_routine3 (id86)       0.640          0.607
# 25     indoor_subject4_routine1 (id14)       0.732          0.583
# 26    indoor_subject4_routine1 (id149)       0.785          0.963
# 27     indoor_subject4_routine1 (id24)       0.691          0.574
# 28     indoor_subject4_routine1 (id28)       0.920          0.919
# 29     indoor_subject4_routine2 (id21)       0.392          0.454
# 30    indoor_subject4_routine2 (id245)       0.489          0.539
# 31     indoor_subject4_routine2 (id77)       0.542          0.455
# 32    indoor_subject4_routine3 (id145)       0.557          0.566
# 33    indoor_subject4_routine3 (id215)       0.507          0.524
# 34     indoor_subject4_routine3 (id68)       0.726          0.670
# 35    indoor_subject5_routine3 (id210)       0.539          0.545
# 36    indoor_subject5_routine3 (id216)       0.652          0.721
# 37    indoor_subject5_routine3 (id217)       0.996          0.595
# 38    indoor_subject6_routine1 (id153)       0.752          0.784
# 39    indoor_subject6_routine3 (id199)       0.566          0.600
# 40     indoor_subject6_routine3 (id30)       0.697          0.708
# 41    indoor_subject7_routine1 (id200)       0.810          0.677
# 42    indoor_subject7_routine1 (id247)       0.755          0.862
# 43     indoor_subject7_routine1 (id49)       0.864          0.860
# 44     indoor_subject7_routine2 (id23)       0.577          0.569
# 45     indoor_subject7_routine2 (id41)       0.661          0.465
# 46    indoor_subject7_routine3 (id105)       0.630          0.635
# 47     indoor_subject7_routine3 (id12)       0.964          0.704
# 48    indoor_subject7_routine3 (id169)       1.000          1.000
# 49    indoor_subject7_routine3 (id196)       0.803          0.462
# 50      indoor_subject7_routine3 (id2)       0.572          0.574
# 51    indoor_subject7_routine3 (id238)       0.871          0.871
# 52    indoor_subject7_routine3 (id246)       0.476          0.450
# 53     indoor_subject7_routine3 (id59)       1.000          1.000
# 54     indoor_subject8_routine1 (id72)       0.902          0.881
# 55     indoor_subject8_routine3 (id11)       0.797          0.709
# 56    indoor_subject8_routine3 (id167)       0.803          0.790
# 57     indoor_subject8_routine3 (id55)       0.992          0.851
# 58    outdoor_subject1_routine1 (id16)       0.739          0.718
# 59   outdoor_subject1_routine1 (id165)       0.658          0.628
# 60   outdoor_subject1_routine2 (id119)       0.434          0.440
# 61   outdoor_subject2_routine1 (id110)       1.000          1.000
# 62   outdoor_subject2_routine1 (id168)       1.000          1.000
# 63   outdoor_subject2_routine1 (id178)       0.545          0.734
# 64   outdoor_subject2_routine1 (id243)       0.973          0.960
# 65    outdoor_subject2_routine1 (id40)       0.960          0.740
# 66   outdoor_subject2_routine2 (id166)       0.297          0.296
# 67   outdoor_subject2_routine3 (id184)       0.168          0.168
# 68    outdoor_subject2_routine3 (id92)       0.536          0.765
# 69   outdoor_subject3_routine1 (id136)       0.810          0.966
# 70    outdoor_subject3_routine1 (id64)       0.519          0.549
# 71   outdoor_subject3_routine2 (id179)       0.432          0.593
# 72   outdoor_subject3_routine2 (id187)       0.453          0.453
# 73    outdoor_subject3_routine2 (id32)       0.260          0.206
# 74    outdoor_subject3_routine2 (id38)       0.438          0.401
# 75    outdoor_subject3_routine2 (id42)       0.794          0.745
# 76    outdoor_subject3_routine2 (id56)       0.320          0.498
# 77   outdoor_subject4_routine1 (id195)       0.707          0.462
# 78   outdoor_subject4_routine1 (id222)       0.667          0.561
# 79   outdoor_subject4_routine2 (id101)       0.255          0.271
# 80   outdoor_subject4_routine2 (id162)       0.804          0.804
# 81   outdoor_subject4_routine2 (id170)       0.913          0.913
# 82    outdoor_subject4_routine2 (id20)       0.788          0.672
# 83    outdoor_subject4_routine2 (id69)       0.519          0.519
# 84   outdoor_subject4_routine3 (id160)       0.827          0.837
# 85   outdoor_subject4_routine3 (id206)       0.426          0.419
# 86    outdoor_subject4_routine3 (id87)       0.364          1.000
# 87    outdoor_subject5_routine1 (id15)       0.700          0.443
# 88   outdoor_subject5_routine1 (id151)       0.463          0.464
# 89   outdoor_subject5_routine1 (id218)       0.872          0.589
# 90   outdoor_subject5_routine1 (id223)       0.727          0.645
# 91    outdoor_subject5_routine1 (id94)       0.938          0.934
# 92   outdoor_subject5_routine2 (id107)       0.369          0.203
# 93    outdoor_subject5_routine2 (id75)       0.242          0.242
# 94    outdoor_subject5_routine2 (id95)       0.664          0.671
# 95   outdoor_subject5_routine3 (id108)       0.758          0.337
# 96   outdoor_subject5_routine3 (id138)       0.799          0.611
# 97   outdoor_subject5_routine3 (id175)       0.720          0.526
# 98   outdoor_subject5_routine3 (id182)       0.947          0.601
# 99   outdoor_subject5_routine3 (id198)       0.469          0.531
# 100   outdoor_subject5_routine3 (id22)       0.962          0.968
# 101  outdoor_subject5_routine3 (id235)       0.385          0.721
# 102    outdoor_subject5_routine3 (id5)       0.971          0.977
# 103   outdoor_subject5_routine3 (id62)       0.855          0.889
# 104   outdoor_subject5_routine3 (id90)       0.965          0.971
# 105  outdoor_subject6_routine1 (id155)       0.475          0.565
# 106  outdoor_subject6_routine3 (id116)       0.914          0.857
# 107  outdoor_subject6_routine3 (id117)       0.647          0.718
# 108  outdoor_subject6_routine3 (id220)       1.000          1.000
# 109   outdoor_subject6_routine3 (id31)       0.821          0.843
# 110   outdoor_subject6_routine3 (id45)       0.908          0.732
# 111   outdoor_subject6_routine3 (id96)       1.000          1.000
# 112  outdoor_subject7_routine1 (id137)       0.630          0.630
# 113  outdoor_subject7_routine1 (id214)       0.697          0.652
# 114  outdoor_subject7_routine3 (id143)       0.966          0.900
# 115  outdoor_subject7_routine3 (id163)       1.000          1.000
# 116  outdoor_subject7_routine3 (id189)       0.591          0.913
# 117  outdoor_subject7_routine3 (id193)       0.770          0.929
# 118  outdoor_subject7_routine3 (id219)       1.000          1.000
# 119    outdoor_subject7_routine3 (id4)       1.000          1.000
# 120   outdoor_subject7_routine3 (id46)       0.825          0.844
# 121   outdoor_subject7_routine3 (id47)       0.866          0.975
# 122   outdoor_subject7_routine3 (id48)       1.000          1.000
# 123   outdoor_subject7_routine3 (id67)       0.759          0.928
# 124   outdoor_subject7_routine3 (id79)       1.000          1.000
#
#      ThresholdProfileAvg
# 0                  0.350
# 1                  0.767
# 2                  0.761
# 3                  0.363
# 4                  0.702
# 5                  0.468
# 6                  0.671
# 7                  0.923
# 8                  0.953
# 9                  0.929
# 10                 0.509
# 11                 0.299
# 12                 0.755
# 13                 0.563
# 14                 0.940
# 15                 0.754
# 16                 0.917
# 17                 0.532
# 18                 0.442
# 19                 0.523
# 20                 0.519
# 21                 0.634
# 22                 0.573
# 23                 0.897
# 24                 0.616
# 25                 0.753
# 26                 0.850
# 27                 0.566
# 28                 0.792
# 29                 0.554
# 30                 0.491
# 31                 0.411
# 32                 0.580
# 33                 0.454
# 34                 0.365
# 35                 0.437
# 36                 0.718
# 37                 0.996
# 38                 0.835
# 39                 0.502
# 40                 0.666
# 41                 0.722
# 42                 0.759
# 43                 0.766
# 44                 0.605
# 45                 0.475
# 46                 0.383
# 47                 0.964
# 48                 1.000
# 49                 0.812
# 50                 0.566
# 51                 0.991
# 52                 0.529
# 53                 1.000
# 54                 0.792
# 55                 0.613
# 56                 0.799
# 57                 0.851
# 58                 0.825
# 59                 0.652
# 60                 0.282
# 61                 0.847
# 62                 1.000
# 63                 0.530
# 64                 0.661
# 65                 0.624
# 66                 0.318
# 67                 0.630
# 68                 0.507
# 69                 0.963
# 70                 0.580
# 71                 0.494
# 72                 0.453
# 73                 0.299
# 74                 0.437
# 75                 0.666
# 76                 0.305
# 77                 0.483
# 78                 0.597
# 79                 0.236
# 80                 0.804
# 81                 0.918
# 82                 0.374
# 83                 0.519
# 84                 0.827
# 85                 0.418
# 86                 0.252
# 87                 0.700
# 88                 0.505
# 89                 0.490
# 90                 0.645
# 91                 0.938
# 92                 0.435
# 93                 0.242
# 94                 0.517
# 95                 0.337
# 96                 0.799
# 97                 0.440
# 98                 0.601
# 99                 1.000
# 100                0.962
# 101                0.494
# 102                0.977
# 103                0.808
# 104                0.841
# 105                0.399
# 106                0.840
# 107                0.718
# 108                1.000
# 109                0.821
# 110                0.728
# 111                1.000
# 112                0.571
# 113                0.612
# 114                0.825
# 115                1.000
# 116                0.485
# 117                0.888
# 118                1.000
# 119                1.000
# 120                0.688
# 121                0.974
# 122                1.000
# 123                0.756
# 124                1.000

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.iloc[:,1:].mean(axis=0).sort_values(ascending=False).round(3)
# Out:
# ProfileAvg             0.702
# MaxProfileAvg          0.695
# ThresholdProfileAvg    0.668
# dtype: float64

# %%
df_scores.iloc[:,1:].median(axis=0).sort_values(ascending=False).round(3)
# Out:
# ProfileAvg             0.727
# MaxProfileAvg          0.695
# ThresholdProfileAvg    0.661
# dtype: float64

# %%
df_scores.iloc[:,1:].std(axis=0).sort_values().round(3)
# Out:
# MaxProfileAvg          0.213
# ThresholdProfileAvg    0.218
# ProfileAvg             0.219
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.iloc[:,1:].rank(1, method='min', ascending=False)
means = np.array(ranks.mean(axis=0))
args = np.argsort(means)

# %%
for mean, name in zip(means[args], df_scores.columns[1:].to_numpy()[args]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# MaxProfileAvg:wins=59 rank=1.7
# ProfileAvg:wins=61 rank=1.7
# ThresholdProfileAvg:wins=44 rank=2.0

# %% [markdown]
# Let's plot the CD diagram.

# %%
ax = plot_critical_difference(
    scores=df_scores.iloc[:, 1:].to_numpy(),
    labels=df_scores.columns[1:].to_numpy(),
    correction="holm",
    alpha=0.05,
)

plt.savefig("../figures/cd_segmentation_profile_averaging.pdf", bbox_inches="tight")

# %% [markdown]
#  Let's plot the MCM.

# %%
dir_path = "../figures/"
file_name = "mcm_segmentation_profile_averaging"

MCM.compare(
    output_dir=dir_path,
    used_statistic="Score",
    save_as_json=False,
    df_results=df_scores.iloc[:, 1:],
    pdf_savename=file_name,
    load_analysis=False,
    pvalue_correction="Holm",
    row_comparates=("MaxProfileAvg",),
    fig_size=(20,5),
    font_size=18,
    precision=3
)
Image(filename=os.path.join(dir_path, file_name + ".pdf"))
# Out:
# Processing ThresholdProfileAvg, MaxProfileAvg:   0%|          | 0/3 [00:00<?, ?it/s]
# <wand.image.Image: 22a58b0 'PDF' (1428x349)>

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "MaxProfileAvg"

for rival in df_scores.columns[1:]:
    if rival == selection: continue

    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method='min', ascending=False)

    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]

    assert wins + losses + ties == pair_ranks.shape[0]

    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# MaxProfileAvg vs ProfileAvg: (wins/ties/losses): 53/20/52
# MaxProfileAvg vs ThresholdProfileAvg: (wins/ties/losses): 66/21/38

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(5, 5))

# sort by median performance
df_sorted_scores = df_scores[df_scores.iloc[:, 1:].median(axis=0).sort_values().index]

df_sorted_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)

ax.set_xticklabels(df_sorted_scores.columns, rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0 + .2, .2), 1))

plt.savefig(f"../figures/bp_segmentation_profile_averaging.pdf", bbox_inches="tight")
